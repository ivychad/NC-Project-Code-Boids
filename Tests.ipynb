# %%
from Plots import *
from ES import *
import pickle
from joblib import Parallel, delayed

# %%
population_size = 10
mutation_rate = 0.3
max_generations = 3 
render = True

# %%
es = EvolutionaryStrategy(population_size=population_size, mutation_rate=mutation_rate, max_generations=max_generations, render= render, predator_strategy="centroid")
all_fitness, all_data = es.run_ES()
# Out:
# Generation 1/3
# Generation 2/3
# Generation 3/3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 es = EvolutionaryStrategy(population_size=population_size, mutation_rate=mutation_rate, max_generations=max_generations, render= render, predator_strategy="centroid")
# ----> 2 all_fitness, all_data = es.run_ES()
#
# File c:\Users\hanna\Downloads\NC Project Code Boids\NC Project Code Boids\ES.py:272, in EvolutionaryStrategy.run_ES(self)
#     269 self.population = elites + flat_offspring
#     271 # Compute fitness after mutation
# --> 272 self.compute_population_fitness()
#     273 self.population.sort()
#     275 # Collect fitness statistics
#
# File c:\Users\hanna\Downloads\NC Project Code Boids\NC Project Code Boids\ES.py:171, in EvolutionaryStrategy.compute_population_fitness(self)
#     165 """
# ...

# %%
plot_coefficients(all_data, coefficient_names=["Separation", "Cohesion", "Alignment", "Dodge", "Repel", "Wiggle"])
plot_fitness_scatter(all_fitness)
